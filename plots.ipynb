# %%
import numpy as np
import matplotlib.pyplot as plt

path = '/u/a/agiorlan/CausalStructureAttention/saved_models/training_losses_num_head_2.npy'
training_losses = np.load(path)

# %%
plt.plot(training_losses)
